# %%
import pandas as pd

tsv_file='/content/dataset.tsv'

# reading given tsv file
csv_table=pd.read_table(tsv_file,sep='\t')

# converting tsv file into csv
csv_table.to_csv('GfG.csv',index=False)

# %%
df=csv_table

# %%
df.head()
# Out:
#    page_id                                               text  label  \
# 0     1012            FLASH SALE | LIMITED TIME ONLY Shop Now      1
# 1      158                                Pillowcases & Shams      0
# 2      108                                     Write a review      0
# 3     1425  To start your return, simply click on the foll...      0
# 4     1658                newsletter signup (privacy policy)       0
#
#    Pattern Category
# 0           Urgency
# 1  Not Dark Pattern
# 2  Not Dark Pattern
# 3  Not Dark Pattern
# 4  Not Dark Pattern

# %%
pip install nlpaug
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install nlpaug torch pandas

# %%
original_data = df.copy()

# %%
import torch
import pandas as pd
import nlpaug.augmenter.word as naw
from nlpaug.util import Action

# Initialize the augmenter
augmenter = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="substitute")

# Assuming you have loaded the data into the 'original_data' DataFrame

# Move the augmenter to the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
augmenter.device=device

# Batch processing for augmentation
batch_size = 64  # You can adjust this based on available GPU memory
num_samples = len(original_data)
augmented_texts = []
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
torch.cuda.is_available()
# Out:
# True

# %%
original_data=df[0:500].copy()

# %%
original_data.head()
# Out:
#    page_id                                               text  label  \
# 0     1012            FLASH SALE | LIMITED TIME ONLY Shop Now      1
# 1      158                                Pillowcases & Shams      0
# 2      108                                     Write a review      0
# 3     1425  To start your return, simply click on the foll...      0
# 4     1658                newsletter signup (privacy policy)       0
#
#    Pattern Category
# 0           Urgency
# 1  Not Dark Pattern
# 2  Not Dark Pattern
# 3  Not Dark Pattern
# 4  Not Dark Pattern

# %%
original_data.shape
# Out:
# (500, 4)

# %%
import torch
import pandas as pd
import nlpaug.augmenter.word as naw
from nlpaug.util import Action

# Initialize the augmenter
augmenter = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="substitute")

# Assuming you have loaded the data into the 'original_data' DataFrame

# Move the augmenter to the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
augmenter.device=device

# Batch processing for augmentation
batch_size = 20  # You can adjust this based on available GPU memory
num_samples = len(original_data)
augmented_texts = []

# %%
for i in range(0, num_samples, batch_size):
    batch_texts = original_data['text'][i:i + batch_size].tolist()
    augmented_batch = augmenter.augment(batch_texts)
    augmented_texts.extend(augmented_batch)

# %%
augmented_data = pd.DataFrame({'text': augmented_texts, 'label': original_data['label'],'Pattern Category':original_data['Pattern Category']})

# %%
df1 = pd.concat([original_data, augmented_data], ignore_index=True)

# %%
df1.head(100)
# Out:
#     page_id                                               text  label  \
# 0    1012.0            FLASH SALE | LIMITED TIME ONLY Shop Now      1
# 1     158.0                                Pillowcases & Shams      0
# 2     108.0                                     Write a review      0
# 3    1425.0  To start your return, simply click on the foll...      0
# 4    1658.0                newsletter signup (privacy policy)       0
# ..      ...                                                ...    ...
# 95   1217.0                            Hurry, only a few left!      1
# 96   1509.0   V&A Collection People Tree’s collaboration wi...      0
# 97   1115.0                                      Only 11 left!      1
# 98   1404.0                        Hurry! Only 6 left in stock      1
# 99    213.0  40 users are currently active on our website j...      1
#
#     Pattern Category
# 0            Urgency
# 1   Not Dark Pattern
# 2   Not Dark Pattern
# 3   Not Dark Pattern
# ...

# %%
original_data=df[500:1000].copy()

# %%
original_data.shape
# Out:
# (500, 4)

# %%
import torch
import pandas as pd
import nlpaug.augmenter.word as naw
from nlpaug.util import Action

# Initialize the augmenter
augmenter = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="substitute")

# Assuming you have loaded the data into the 'original_data' DataFrame

# Move the augmenter to the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
augmenter.device=device

# Batch processing for augmentation
batch_size = 20  # You can adjust this based on available GPU memory
num_samples = len(original_data)
augmented_texts = []

# %%
for i in range(0, num_samples, batch_size):
    batch_texts = original_data['text'][i:i + batch_size].tolist()
    augmented_batch = augmenter.augment(batch_texts)
    augmented_texts.extend(augmented_batch)

# %%
augmented_data = pd.DataFrame({'text': augmented_texts, 'label': original_data['label'],'Pattern Category':original_data['Pattern Category']})

# %%
df2 = pd.concat([original_data, augmented_data], ignore_index=True)

# %%
df2.shape
# Out:
# (1000, 4)

# %%
df2.head()
# Out:
#    page_id                                               text  label  \
# 0    845.0                                     1 day 08:15:25      1
# 1    173.0  estiven in Deer Park, United States purchased ...      1
# 2    833.0                            Delivery & Offers Terms      0
# 3    106.0               Oscar from Cajamarca, Peru purchased      1
# 4    353.0                                       New Arrivals      0
#
#    Pattern Category
# 0           Urgency
# 1      Social Proof
# 2  Not Dark Pattern
# 3      Social Proof
# 4  Not Dark Pattern

# %%
original_data=df[1000:1500].copy()

# %%
original_data.shape
# Out:
# (500, 4)

# %%
import torch
import pandas as pd
import nlpaug.augmenter.word as naw
from nlpaug.util import Action

# Initialize the augmenter
augmenter = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="substitute")

# Assuming you have loaded the data into the 'original_data' DataFrame

# Move the augmenter to the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
augmenter.device=device

# Batch processing for augmentation
batch_size = 20  # You can adjust this based on available GPU memory
num_samples = len(original_data)
augmented_texts = []

# %%
for i in range(0, num_samples, batch_size):
    batch_texts = original_data['text'][i:i + batch_size].tolist()
    augmented_batch = augmenter.augment(batch_texts)
    augmented_texts.extend(augmented_batch)

# %%
augmented_data = pd.DataFrame({'text': augmented_texts, 'label': original_data['label'],'Pattern Category':original_data['Pattern Category']})

# %%
df3 = pd.concat([original_data, augmented_data], ignore_index=True)

# %%
df3.shape
# Out:
# (1000, 4)

# %%
df3.tail(10)
# Out:
#      page_id                                               text  label  \
# 990      NaN                 12 of take this product worldwide!      1
# 991      NaN                                      wherein [UNK]      0
# 992      NaN                                    graphic version      0
# 993      NaN                       low stock (... 100 points! )      1
# 994      NaN  john in australia city, australia purchased st...      1
# 995      NaN   a - neck printed white short - pressed h - shirt      0
# 996      NaN                  limited time none · devotion only      1
# 997      NaN                                        first times      0
# 998      NaN                                                  ॥      0
# 999      NaN                                      locus remotes      0
#
#      Pattern Category
# 990      Social Proof
# 991  Not Dark Pattern
# 992  Not Dark Pattern
# 993          Scarcity
# 994      Social Proof
# 995  Not Dark Pattern
# 996           Urgency
# ...

# %%
original_data=df[1500:].copy()

# %%
original_data.shape
# Out:
# (856, 4)

# %%
import torch
import pandas as pd
import nlpaug.augmenter.word as naw
from nlpaug.util import Action

# Initialize the augmenter
augmenter = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="substitute")

# Assuming you have loaded the data into the 'original_data' DataFrame

# Move the augmenter to the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
augmenter.device=device

# Batch processing for augmentation
batch_size = 20  # You can adjust this based on available GPU memory
num_samples = len(original_data)
augmented_texts = []

# %%
for i in range(0, num_samples, batch_size):
    batch_texts = original_data['text'][i:i + batch_size].tolist()
    augmented_batch = augmenter.augment(batch_texts)
    augmented_texts.extend(augmented_batch)

# %%
augmented_data = pd.DataFrame({'text': augmented_texts, 'label': original_data['label'],'Pattern Category':original_data['Pattern Category']})

# %%
df4 = pd.concat([original_data, augmented_data], ignore_index=True)

# %%
df4.shape
# Out:
# (1712, 4)

# %%
df4.tail(100)
# Out:
#       page_id                                               text  label  \
# 1612      NaN                  people should celebrate this with      1
# 1613      NaN                    snap! released 31 cds in stock.      1
# 1614      NaN                           creation date with [UNK]      0
# 1615      NaN                                   chapter 16 left.      1
# 1616      NaN  wish your loved ones instantly is ferns n leav...      0
# ...       ...                                                ...    ...
# 1707      NaN                                         a panty xi      0
# 1708      NaN  dress & wear & perfume the - first me - first ...      0
# 1709      NaN                              score 4 left in years      1
# 1710      NaN                                       idol players      0
# 1711      NaN                              10 furlongs for stock      1
#
#       Pattern Category
# 1612      Misdirection
# 1613          Scarcity
# 1614  Not Dark Pattern
# ...

# %%
newdf=pd.concat([df1,df2,df3,df4],ignore_index=True)

# %%
newdf.shape
# Out:
# (4712, 4)

# %%
newdf.label.value_counts()
# Out:
# 1    2356
# 0    2356
# Name: label, dtype: int64

# %%
df=newdf

# %%
df.head(100)
# Out:
#     page_id                                               text  label  \
# 0    1012.0            FLASH SALE | LIMITED TIME ONLY Shop Now      1
# 1     158.0                                Pillowcases & Shams      0
# 2     108.0                                     Write a review      0
# 3    1425.0  To start your return, simply click on the foll...      0
# 4    1658.0                newsletter signup (privacy policy)       0
# ..      ...                                                ...    ...
# 95   1217.0                            Hurry, only a few left!      1
# 96   1509.0   V&A Collection People Tree’s collaboration wi...      0
# 97   1115.0                                      Only 11 left!      1
# 98   1404.0                        Hurry! Only 6 left in stock      1
# 99    213.0  40 users are currently active on our website j...      1
#
#     Pattern Category
# 0            Urgency
# 1   Not Dark Pattern
# 2   Not Dark Pattern
# 3   Not Dark Pattern
# ...

# %%
df.to_csv('/content/sample_data/aug_data.csv')

# %%
import pandas as pd
df5=pd.read_csv('/content/sample_data/aug_data.csv')
df5
# Out:
#       Unnamed: 0  page_id                                               text  \
# 0              0   1012.0            FLASH SALE | LIMITED TIME ONLY Shop Now
# 1              1    158.0                                Pillowcases & Shams
# 2              2    108.0                                     Write a review
# 3              3   1425.0  To start your return, simply click on the foll...
# 4              4   1658.0                newsletter signup (privacy policy)
# ...          ...      ...                                                ...
# 4707        4707      NaN                                         a panty xi
# 4708        4708      NaN  dress & wear & perfume the - first me - first ...
# 4709        4709      NaN                              score 4 left in years
# 4710        4710      NaN                                       idol players
# 4711        4711      NaN                              10 furlongs for stock
#
#       label  Pattern Category
# ...

# %%
df.shape
# Out:
# (4712, 4)
